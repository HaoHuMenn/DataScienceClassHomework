# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"
users = pd.read_csv(url, sep = "|", index_col = "user_id")
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
occupation_grp = users.groupby(["occupation"])
occupation_grp["age"].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
# get rid of heirarchical indexing, so that can be a dataframe group
occupation_grp1 = users.groupby(["occupation"], as_index = False)

#dataframe
df = occupation_grp1["gender"].value_counts(normalize = True) # normalize = True turns count into %
# convert to % 
df["gender%"] = df["proportion"] *100
filt = df["gender"] == "M"
df[filt].sort_values(by = "gender%", ascending = False)
# Out:
#        occupation gender  proportion     gender%
# 4          doctor      M    1.000000  100.000000
# 7        engineer      M    0.970149   97.014925
# 37     technician      M    0.962963   96.296296
# 29        retired      M    0.928571   92.857143
# 27     programmer      M    0.909091   90.909091
# 11      executive      M    0.906250   90.625000
# 33      scientist      M    0.903226   90.322581
# 9   entertainment      M    0.888889   88.888889
# 17         lawyer      M    0.833333   83.333333
# 31       salesman      M    0.750000   75.000000
# 5        educator      M    0.726316   72.631579
# 35        student      M    0.693878   69.387755
# 25          other      M    0.657143   65.714286
# 21      marketing      M    0.615385   61.538462
# 39         writer      M    0.577778   57.777778
# 23           none      M    0.555556   55.555556
# 0   administrator      M    0.544304   54.430380
# 2          artist      M    0.535714   53.571429
# ...

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
occupation_grp["age"].agg(["min", "max"])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
occupation_gender_grp = users.groupby(["occupation", "gender"])
occupation_gender_grp["age"].agg(["mean"])
# Out:
#                            mean
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
occupation_grp["gender"].value_counts(normalize = True) * 100
# Out:
# occupation     gender
# administrator  M          54.430380
#                F          45.569620
# artist         M          53.571429
#                F          46.428571
# doctor         M         100.000000
# educator       M          72.631579
#                F          27.368421
# engineer       M          97.014925
#                F           2.985075
# entertainment  M          88.888889
#                F          11.111111
# executive      M          90.625000
#                F           9.375000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         M          83.333333
#                F          16.666667
# librarian      F          56.862745
#                M          43.137255
# marketing      M          61.538462
#                F          38.461538
# none           M          55.555556
#                F          44.444444
# ...
